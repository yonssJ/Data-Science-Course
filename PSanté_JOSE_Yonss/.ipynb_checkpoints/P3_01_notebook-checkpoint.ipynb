# %% [markdown]
# # Projets -  idées  innovantes d’applications en lien avec l'alimentation
#
# ## Résumé
#
# On veut savoir les aliments les plus addapté pour une personne que envisage d'aquerir de bonnes habitudes alimentaires. On cherche donc à prédire la présence de graisses saturées, omega 3, omega 6, omega 9, du sel et sucre non necessaire, vitamines, fibres, mineraux, proteines et calcium. Cela en evitant les additifs et on previlegient les aliments avec un nutriscore et ecoscore favorable.
#
# ## Méthode

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
from pandas import Series

# %%
def group_and_loc_group(df,categ):
    grouped = df.groupby(categ, as_index=False)
    df_grouped=[]
    for i in grouped.groups.keys():
        loc=grouped.groups[i]
        df_grouped.append(pd.DataFrame(df.iloc[loc]))
    return grouped, df_grouped

# %% [markdown]
# ### Telechargement des données

# %%
pd.set_option("display.precision", 2)          
pd.set_option("display.max.columns", None)    
pd.set_option("display.max.rows", None)

file = pathlib.Path('../../P3/DATA/FR.openfoodfacts.org.products.csv')

if file.exists ():
    df =pd.read_csv('../../P3/DATA/FR.openfoodfacts.org.products.csv')
    print ("File exist")
else:
    df = pd.read_csv("../../P3/DATA/en.openfoodfacts.org.products.csv",
                     sep="\t", encoding="utf-8", nrows=15000, low_memory=False)
# Je n'arrive pas à separer par à cause des nan
    df['countries_en']=df['countries_en'].fillna('MISSING COUNTRY')
#Selectioner seulement les donnees du marche Français vu que le projet est pour la France
    groupby = ['countries_en']
    [grouped, df_grouped] = group_and_loc_group(df,groupby)
    
    for group in df_grouped:
        if ',' in str(group[groupby]):
            if group['countries_en'].str.contains('France').any():
                s = group['countries_en'].str.split(',').apply(Series, 1).stack()
                s.index = s.index.droplevel(-1) # to line up with df's index
                s.name = 'France' # needs a name to join
                del group['countries_en']
                group.join(s)
                
#     df.to_csv ('../../P3/DATA/FR.openfoodfacts.org.products.csv', index = False, header=True)
#     print ("Create FR File")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-e367bed4d439> in <module>
#      24                 s.name = 'France' # needs a name to join
#      25                 del group['countries_en']
# ---> 26                 aa=append(group.join(s))
#      27
#      28 #     df.to_csv ('../../P3/DATA/FR.openfoodfacts.org.products.csv', index = False, header=True)
#
# NameError: name 'append' is not defined

# %%
cc.tail()
# Out:
#                 code                                                url  \
# 14041  0011210008557  http://world-en.openfoodfacts.org/product/0011...
# 14049  0011210009301  http://world-en.openfoodfacts.org/product/0011...
# 14049  0011210009301  http://world-en.openfoodfacts.org/product/0011...
# 14062  0011210021501  http://world-en.openfoodfacts.org/product/0011...
# 14062  0011210021501  http://world-en.openfoodfacts.org/product/0011...
#
#                creator   created_t      created_datetime  last_modified_t  \
# 14041          kiliweb  1544966047  2018-12-16T13:14:07Z       1587665447
# 14049  usda-ndb-import  1489142810  2017-03-10T10:46:50Z       1587635022
# 14049  usda-ndb-import  1489142810  2017-03-10T10:46:50Z       1587635022
# 14062  usda-ndb-import  1489057262  2017-03-09T11:01:02Z       1587574439
# 14062  usda-ndb-import  1489057262  2017-03-09T11:01:02Z       1587574439
#
#       last_modified_datetime        product_name  abbreviated_product_name  \
# 14041   2020-04-23T18:10:47Z      Scorpion sauce                       NaN
# 14049   2020-04-23T09:43:42Z  Green pepper sauce                       NaN
# 14049   2020-04-23T09:43:42Z  Green pepper sauce                       NaN
# 14062   2020-04-22T16:53:59Z       Spicy ketchup                       NaN
# 14062   2020-04-22T16:53:59Z       Spicy ketchup                       NaN
#
#       generic_name quantity packaging packaging_tags packaging_text  \
# 14041          NaN      NaN       NaN            NaN            NaN
# 14049          NaN      NaN       NaN            NaN            NaN
# 14049          NaN      NaN       NaN            NaN            NaN
# 14062          NaN      NaN       NaN            NaN            NaN
# 14062          NaN      NaN       NaN            NaN            NaN
#
#                   brands        brands_tags  \
# 14041                NaN                NaN
# 14049  Mcllhenny Company  mcllhenny-company
# 14049  Mcllhenny Company  mcllhenny-company
# 14062            Tabasco            tabasco
# 14062            Tabasco            tabasco
#
#                                       categories  \
# 14041                          Groceries, Sauces
# 14049                          Groceries, Sauces
# 14049                          Groceries, Sauces
# 14062  Groceries, Sauces, Tomato sauces, Ketchup
# 14062  Groceries, Sauces, Tomato sauces, Ketchup
#
#                                          categories_tags  \
# 14041                             en:groceries,en:sauces
# 14049                             en:groceries,en:sauces
# 14049                             en:groceries,en:sauces
# 14062  en:groceries,en:sauces,en:tomato-sauces,en:ket...
# 14062  en:groceries,en:sauces,en:tomato-sauces,en:ket...
#
#                                 categories_en origins origins_tags origins_en  \
# 14041                        Groceries,Sauces     NaN          NaN        NaN
# 14049                        Groceries,Sauces     NaN          NaN        NaN
# 14049                        Groceries,Sauces     NaN          NaN        NaN
# 14062  Groceries,Sauces,Tomato sauces,Ketchup     NaN          NaN        NaN
# 14062  Groceries,Sauces,Tomato sauces,Ketchup     NaN          NaN        NaN
#
#       manufacturing_places manufacturing_places_tags labels labels_tags  \
# 14041                  NaN                       NaN    NaN         NaN
# 14049                  NaN                       NaN    NaN         NaN
# 14049                  NaN                       NaN    NaN         NaN
# 14062                  NaN                       NaN    NaN         NaN
# 14062                  NaN                       NaN    NaN         NaN
#
#       labels_en emb_codes emb_codes_tags first_packaging_code_geo  cities  \
# 14041       NaN       NaN            NaN                      NaN     NaN
# 14049       NaN       NaN            NaN                      NaN     NaN
# 14049       NaN       NaN            NaN                      NaN     NaN
# 14062       NaN       NaN            NaN                      NaN     NaN
# 14062       NaN       NaN            NaN                      NaN     NaN
#
#       cities_tags purchase_places stores                 countries  \
# 14041         NaN             NaN    NaN  en:france, United States
# 14049         NaN             NaN    NaN     France, United States
# 14049         NaN             NaN    NaN     France, United States
# 14062         NaN             NaN    NaN     France, United States
# 14062         NaN             NaN    NaN     France, United States
#
#                    countries_tags  \
# 14041  en:france,en:united-states
# 14049  en:france,en:united-states
# 14049  en:france,en:united-states
# 14062  en:france,en:united-states
# 14062  en:france,en:united-states
#
#                                         ingredients_text allergens  \
# 14041  Scorpion pepper, distilled vinegar, sugar, gua...       NaN
# 14049  Distilled vinegar, jalapeno pepper, water, sal...       NaN
# 14049  Distilled vinegar, jalapeno pepper, water, sal...       NaN
# 14062  Tomato concentrate (water and tomato paste), c...       NaN
# 14062  Tomato concentrate (water and tomato paste), c...       NaN
#
#        allergens_en traces traces_tags traces_en   serving_size  \
# 14041           NaN    NaN         NaN       NaN   1 tsp (5 ml)
# 14049           NaN    NaN         NaN       NaN   1 tsp (5 ml)
# 14049           NaN    NaN         NaN       NaN   1 tsp (5 ml)
# 14062           NaN    NaN         NaN       NaN  1 Tbsp (17 g)
# 14062           NaN    NaN         NaN       NaN  1 Tbsp (17 g)
#
#        serving_quantity  no_nutriments  additives_n  additives additives_tags  \
# 14041               5.0            NaN          0.0        NaN            NaN
# 14049               5.0            NaN          1.0        NaN        en:e415
# 14049               5.0            NaN          1.0        NaN        en:e415
# 14062              17.0            NaN          0.0        NaN            NaN
# 14062              17.0            NaN          0.0        NaN            NaN
#
#              additives_en  ingredients_from_palm_oil_n  \
# 14041                 NaN                          0.0
# 14049  E415 - Xanthan gum                          0.0
# 14049  E415 - Xanthan gum                          0.0
# 14062                 NaN                          0.0
# 14062                 NaN                          0.0
#
#        ingredients_from_palm_oil ingredients_from_palm_oil_tags  \
# 14041                        NaN                            NaN
# 14049                        NaN                            NaN
# 14049                        NaN                            NaN
# 14062                        NaN                            NaN
# 14062                        NaN                            NaN
#
#        ingredients_that_may_be_from_palm_oil_n  \
# 14041                                      0.0
# 14049                                      0.0
# 14049                                      0.0
# 14062                                      0.0
# 14062                                      0.0
#
#        ingredients_that_may_be_from_palm_oil  \
# 14041                                    NaN
# 14049                                    NaN
# 14049                                    NaN
# 14062                                    NaN
# 14062                                    NaN
#
#       ingredients_that_may_be_from_palm_oil_tags  nutriscore_score  \
# 14041                                        NaN              14.0
# 14049                                        NaN              10.0
# 14049                                        NaN              10.0
# 14062                                        NaN              12.0
# 14062                                        NaN              12.0
#
#       nutriscore_grade  nova_group   pnns_groups_1         pnns_groups_2  \
# 14041                d         3.0  Fat and sauces  Dressings and sauces
# 14049                c         4.0  Fat and sauces  Dressings and sauces
# 14049                c         4.0  Fat and sauces  Dressings and sauces
# 14062                d         4.0  Fat and sauces  Dressings and sauces
# 14062                d         4.0  Fat and sauces  Dressings and sauces
#
#                                                   states  \
# 14041  en:to-be-completed, en:nutrition-facts-complet...
# 14049  en:to-be-completed, en:nutrition-facts-complet...
# 14049  en:to-be-completed, en:nutrition-facts-complet...
# 14062  en:to-be-completed, en:nutrition-facts-complet...
# 14062  en:to-be-completed, en:nutrition-facts-complet...
#
#                                              states_tags  \
# 14041  en:to-be-completed,en:nutrition-facts-complete...
# 14049  en:to-be-completed,en:nutrition-facts-complete...
# 14049  en:to-be-completed,en:nutrition-facts-complete...
# 14062  en:to-be-completed,en:nutrition-facts-complete...
# 14062  en:to-be-completed,en:nutrition-facts-complete...
#
#                                                states_en        brand_owner  \
# 14041  To be completed,Nutrition facts completed,Ingr...  McIlhenny Company
# 14049  To be completed,Nutrition facts completed,Ingr...  McIlhenny Company
# 14049  To be completed,Nutrition facts completed,Ingr...  McIlhenny Company
# 14062  To be completed,Nutrition facts completed,Ingr...  McIlhenny Company
# 14062  To be completed,Nutrition facts completed,Ingr...  McIlhenny Company
#
#        ecoscore_score_fr ecoscore_grade_fr main_category main_category_en  \
# 14041                NaN               NaN     en:sauces           Sauces
# 14049                NaN               NaN     en:sauces           Sauces
# 14049                NaN               NaN     en:sauces           Sauces
# 14062               79.0                 b    en:ketchup          Ketchup
# 14062               79.0                 b    en:ketchup          Ketchup
#
#                                                image_url  \
# 14041                                                NaN
# 14049                                                NaN
# 14049                                                NaN
# 14062  https://static.openfoodfacts.org/images/produc...
# 14062  https://static.openfoodfacts.org/images/produc...
#
#                                          image_small_url  \
# 14041                                                NaN
# 14049                                                NaN
# 14049                                                NaN
# 14062  https://static.openfoodfacts.org/images/produc...
# 14062  https://static.openfoodfacts.org/images/produc...
#
#                                    image_ingredients_url  \
# 14041                                                NaN
# 14049  https://static.openfoodfacts.org/images/produc...
# 14049  https://static.openfoodfacts.org/images/produc...
# 14062  https://static.openfoodfacts.org/images/produc...
# 14062  https://static.openfoodfacts.org/images/produc...
#
#                              image_ingredients_small_url image_nutrition_url  \
# 14041                                                NaN                 NaN
# 14049  https://static.openfoodfacts.org/images/produc...                 NaN
# 14049  https://static.openfoodfacts.org/images/produc...                 NaN
# 14062  https://static.openfoodfacts.org/images/produc...                 NaN
# 14062  https://static.openfoodfacts.org/images/produc...                 NaN
#
#       image_nutrition_small_url  energy-kj_100g  energy-kcal_100g  \
# 14041                       NaN             NaN               0.0
# 14049                       NaN             NaN               0.0
# 14049                       NaN             NaN               0.0
# 14062                       NaN             NaN             118.0
# 14062                       NaN             NaN             118.0
#
#        energy_100g  energy-from-fat_100g  fat_100g  saturated-fat_100g  \
# 14041          0.0                   NaN       0.0                 1.0
# 14049          0.0                   NaN       0.0                 0.0
# 14049          0.0                   NaN       0.0                 0.0
# 14062        494.0                   NaN       0.0                 0.0
# 14062        494.0                   NaN       0.0                 0.0
#
#        -butyric-acid_100g  -caproic-acid_100g  -caprylic-acid_100g  \
# 14041                 NaN                 NaN                  NaN
# 14049                 NaN                 NaN                  NaN
# 14049                 NaN                 NaN                  NaN
# 14062                 NaN                 NaN                  NaN
# 14062                 NaN                 NaN                  NaN
#
#        -capric-acid_100g  -lauric-acid_100g  -myristic-acid_100g  \
# 14041                NaN                NaN                  NaN
# 14049                NaN                NaN                  NaN
# 14049                NaN                NaN                  NaN
# 14062                NaN                NaN                  NaN
# 14062                NaN                NaN                  NaN
#
#        -palmitic-acid_100g  -stearic-acid_100g  -arachidic-acid_100g  \
# 14041                  NaN                 NaN                   NaN
# 14049                  NaN                 NaN                   NaN
# 14049                  NaN                 NaN                   NaN
# 14062                  NaN                 NaN                   NaN
# 14062                  NaN                 NaN                   NaN
#
#        -behenic-acid_100g  -lignoceric-acid_100g  -cerotic-acid_100g  \
# 14041                 NaN                    NaN                 NaN
# 14049                 NaN                    NaN                 NaN
# 14049                 NaN                    NaN                 NaN
# 14062                 NaN                    NaN                 NaN
# 14062                 NaN                    NaN                 NaN
#
#        -montanic-acid_100g  -melissic-acid_100g  monounsaturated-fat_100g  \
# 14041                  NaN                  NaN                       NaN
# 14049                  NaN                  NaN                       NaN
# 14049                  NaN                  NaN                       NaN
# 14062                  NaN                  NaN                       NaN
# 14062                  NaN                  NaN                       NaN
#
#        polyunsaturated-fat_100g  omega-3-fat_100g  -alpha-linolenic-acid_100g  \
# 14041                       NaN               NaN                         NaN
# 14049                       NaN               NaN                         NaN
# 14049                       NaN               NaN                         NaN
# 14062                       NaN               NaN                         NaN
# 14062                       NaN               NaN                         NaN
#
#        -eicosapentaenoic-acid_100g  -docosahexaenoic-acid_100g  \
# 14041                          NaN                         NaN
# 14049                          NaN                         NaN
# 14049                          NaN                         NaN
# 14062                          NaN                         NaN
# 14062                          NaN                         NaN
#
#        omega-6-fat_100g  -linoleic-acid_100g  -arachidonic-acid_100g  \
# 14041               NaN                  NaN                     NaN
# 14049               NaN                  NaN                     NaN
# 14049               NaN                  NaN                     NaN
# 14062               NaN                  NaN                     NaN
# 14062               NaN                  NaN                     NaN
#
#        -gamma-linolenic-acid_100g  -dihomo-gamma-linolenic-acid_100g  \
# 14041                         NaN                                NaN
# 14049                         NaN                                NaN
# 14049                         NaN                                NaN
# 14062                         NaN                                NaN
# 14062                         NaN                                NaN
#
#        omega-9-fat_100g  -oleic-acid_100g  -elaidic-acid_100g  \
# 14041               NaN               NaN                 NaN
# 14049               NaN               NaN                 NaN
# 14049               NaN               NaN                 NaN
# 14062               NaN               NaN                 NaN
# 14062               NaN               NaN                 NaN
#
#        -gondoic-acid_100g  -mead-acid_100g  -erucic-acid_100g  \
# 14041                 NaN              NaN                NaN
# 14049                 NaN              NaN                NaN
# 14049                 NaN              NaN                NaN
# 14062                 NaN              NaN                NaN
# 14062                 NaN              NaN                NaN
#
#        -nervonic-acid_100g  trans-fat_100g  cholesterol_100g  \
# 14041                  NaN             0.0               NaN
# 14049                  NaN             0.0               NaN
# 14049                  NaN             0.0               NaN
# 14062                  NaN             0.0               NaN
# 14062                  NaN             0.0               NaN
#
#        carbohydrates_100g  sugars_100g  -sucrose_100g  -glucose_100g  \
# 14041               20.00        20.00            NaN            NaN
# 14049                0.00         0.00            NaN            NaN
# 14049                0.00         0.00            NaN            NaN
# 14062               29.41        11.76            NaN            NaN
# 14062               29.41        11.76            NaN            NaN
#
#        -fructose_100g  -lactose_100g  -maltose_100g  -maltodextrins_100g  \
# 14041             NaN            NaN            NaN                  NaN
# 14049             NaN            NaN            NaN                  NaN
# 14049             NaN            NaN            NaN                  NaN
# 14062             NaN            NaN            NaN                  NaN
# 14062             NaN            NaN            NaN                  NaN
#
#        starch_100g  polyols_100g  fiber_100g  -soluble-fiber_100g  \
# 14041          NaN           NaN         NaN                  NaN
# 14049          NaN           NaN         NaN                  NaN
# 14049          NaN           NaN         NaN                  NaN
# 14062          NaN           NaN         NaN                  NaN
# 14062          NaN           NaN         NaN                  NaN
#
#        -insoluble-fiber_100g  proteins_100g  casein_100g  serum-proteins_100g  \
# 14041                    NaN            0.0          NaN                  NaN
# 14049                    NaN            0.0          NaN                  NaN
# 14049                    NaN            0.0          NaN                  NaN
# 14062                    NaN            0.0          NaN                  NaN
# 14062                    NaN            0.0          NaN                  NaN
#
#        nucleotides_100g  salt_100g  sodium_100g  alcohol_100g  vitamin-a_100g  \
# 14041               NaN       9.50         3.80           NaN             NaN
# 14049               NaN       7.50         3.00           NaN             NaN
# 14049               NaN       7.50         3.00           NaN             NaN
# 14062               NaN       2.06         0.82           NaN             NaN
# 14062               NaN       2.06         0.82           NaN             NaN
#
#        beta-carotene_100g  vitamin-d_100g  vitamin-e_100g  vitamin-k_100g  \
# 14041                 NaN             NaN             NaN             NaN
# 14049                 NaN             NaN             NaN             NaN
# 14049                 NaN             NaN             NaN             NaN
# 14062                 NaN             NaN             NaN             NaN
# 14062                 NaN             NaN             NaN             NaN
#
#        vitamin-c_100g  vitamin-b1_100g  vitamin-b2_100g  vitamin-pp_100g  \
# 14041             NaN              NaN              NaN              NaN
# 14049            0.07              NaN              NaN              NaN
# 14049            0.07              NaN              NaN              NaN
# 14062             NaN              NaN              NaN              NaN
# 14062             NaN              NaN              NaN              NaN
#
#        vitamin-b6_100g  vitamin-b9_100g  folates_100g  vitamin-b12_100g  \
# 14041              NaN              NaN           NaN               NaN
# 14049              NaN              NaN           NaN               NaN
# 14049              NaN              NaN           NaN               NaN
# 14062              NaN              NaN           NaN               NaN
# 14062              NaN              NaN           NaN               NaN
#
#        biotin_100g  pantothenic-acid_100g  silica_100g  bicarbonate_100g  \
# 14041          NaN                    NaN          NaN               NaN
# 14049          NaN                    NaN          NaN               NaN
# 14049          NaN                    NaN          NaN               NaN
# 14062          NaN                    NaN          NaN               NaN
# 14062          NaN                    NaN          NaN               NaN
#
#        potassium_100g  chloride_100g  calcium_100g  phosphorus_100g  \
# 14041             NaN            NaN           NaN              NaN
# 14049             NaN            NaN           NaN              NaN
# 14049             NaN            NaN           NaN              NaN
# 14062             NaN            NaN           NaN              NaN
# 14062             NaN            NaN           NaN              NaN
#
#        iron_100g  magnesium_100g  zinc_100g  copper_100g  manganese_100g  \
# 14041        NaN             NaN        NaN          NaN             NaN
# 14049        NaN             NaN        NaN          NaN             NaN
# 14049        NaN             NaN        NaN          NaN             NaN
# 14062        NaN             NaN        NaN          NaN             NaN
# 14062        NaN             NaN        NaN          NaN             NaN
#
#        fluoride_100g  selenium_100g  chromium_100g  molybdenum_100g  \
# 14041            NaN            NaN            NaN              NaN
# 14049            NaN            NaN            NaN              NaN
# 14049            NaN            NaN            NaN              NaN
# 14062            NaN            NaN            NaN              NaN
# 14062            NaN            NaN            NaN              NaN
#
#        iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 14041          NaN            NaN           NaN      NaN
# 14049          NaN            NaN           NaN      NaN
# 14049          NaN            NaN           NaN      NaN
# 14062          NaN            NaN           NaN      NaN
# 14062          NaN            NaN           NaN      NaN
#
#        fruits-vegetables-nuts_100g  fruits-vegetables-nuts-dried_100g  \
# 14041                          NaN                                NaN
# 14049                          NaN                                NaN
# 14049                          NaN                                NaN
# 14062                          NaN                                NaN
# 14062                          NaN                                NaN
#
#        fruits-vegetables-nuts-estimate_100g  collagen-meat-protein-ratio_100g  \
# 14041                                   NaN                               NaN
# 14049                                   NaN                               NaN
# 14049                                   NaN                               NaN
# 14062                                   NaN                               NaN
# 14062                                   NaN                               NaN
#
#        cocoa_100g  chlorophyl_100g  carbon-footprint_100g  \
# 14041         NaN              NaN                    NaN
# 14049         NaN              NaN                    NaN
# 14049         NaN              NaN                    NaN
# 14062         NaN              NaN                    NaN
# 14062         NaN              NaN                    NaN
#
#        carbon-footprint-from-meat-or-fish_100g  nutrition-score-fr_100g  \
# 14041                                      NaN                     14.0
# 14049                                      NaN                     10.0
# 14049                                      NaN                     10.0
# 14062                                      NaN                     12.0
# 14062                                      NaN                     12.0
#
#        nutrition-score-uk_100g  glycemic-index_100g  water-hardness_100g  \
# 14041                      NaN                  NaN                  NaN
# 14049                      NaN                  NaN                  NaN
# 14049                      NaN                  NaN                  NaN
# 14062                      NaN                  NaN                  NaN
# 14062                      NaN                  NaN                  NaN
#
#        choline_100g  phylloquinone_100g  beta-glucan_100g  inositol_100g  \
# 14041           NaN                 NaN               NaN            NaN
# 14049           NaN                 NaN               NaN            NaN
# 14049           NaN                 NaN               NaN            NaN
# 14062           NaN                 NaN               NaN            NaN
# 14062           NaN                 NaN               NaN            NaN
#
#        carnitine_100g         France
# 14041             NaN  United States
# 14049             NaN         France
# 14049             NaN  United States
# 14062             NaN         France
# 14062             NaN  United States

# %%
group.head() #.T.to_excel("../../P3/FIGURES/e.xlsx")
# Out:
#               code                                                url  \
# 57   0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 58   0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 116  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 117  0000000016094  http://world-en.openfoodfacts.org/product/0000...
# 118  0000000016100  http://world-en.openfoodfacts.org/product/0000...
#
#              creator   created_t      created_datetime  last_modified_t  \
# 57   usda-ndb-import  1489069957  2017-03-09T14:32:37Z       1489069957
# 58   usda-ndb-import  1489069957  2017-03-09T14:32:37Z       1489069957
# 116  usda-ndb-import  1489055731  2017-03-09T10:35:31Z       1545997008
# 117  usda-ndb-import  1489055653  2017-03-09T10:34:13Z       1545997008
# 118  usda-ndb-import  1489055651  2017-03-09T10:34:11Z       1489055651
#
#     last_modified_datetime                       product_name  \
# 57    2017-03-09T14:32:37Z     Banana Chips Sweetened (Whole)
# 58    2017-03-09T14:32:37Z                            Peanuts
# 116   2018-12-28T11:36:48Z             Organic Salted Nut Mix
# 117   2018-12-28T11:36:48Z                    Organic Polenta
# 118   2017-03-09T10:34:11Z  Breadshop Honey Gone Nuts Granola
#
#      abbreviated_product_name generic_name quantity packaging packaging_tags  \
# 57                        NaN          NaN      NaN       NaN            NaN
# 58                        NaN          NaN      NaN       NaN            NaN
# 116                       NaN          NaN      NaN       NaN            NaN
# 117                       NaN          NaN      NaN       NaN            NaN
# 118                       NaN          NaN      NaN       NaN            NaN
#
#     packaging_text          brands     brands_tags categories categories_tags  \
# 57             NaN             NaN             NaN        NaN             NaN
# 58             NaN  Torn & Glasser    torn-glasser        NaN             NaN
# 116            NaN       Grizzlies       grizzlies        NaN             NaN
# 117            NaN  Bob's Red Mill  bob-s-red-mill        NaN             NaN
# 118            NaN            Unfi            unfi        NaN             NaN
#
#     categories_en origins origins_tags origins_en manufacturing_places  \
# 57            NaN     NaN          NaN        NaN                  NaN
# 58            NaN     NaN          NaN        NaN                  NaN
# 116           NaN     NaN          NaN        NaN                  NaN
# 117           NaN     NaN          NaN        NaN                  NaN
# 118           NaN     NaN          NaN        NaN                  NaN
#
#     manufacturing_places_tags   labels labels_tags labels_en emb_codes  \
# 57                        NaN      NaN         NaN       NaN       NaN
# 58                        NaN      NaN         NaN       NaN       NaN
# 116                       NaN  Organic  en:organic   Organic       NaN
# 117                       NaN  Organic  en:organic   Organic       NaN
# 118                       NaN      NaN         NaN       NaN       NaN
#
#     emb_codes_tags first_packaging_code_geo  cities cities_tags  \
# 57             NaN                      NaN     NaN         NaN
# 58             NaN                      NaN     NaN         NaN
# 116            NaN                      NaN     NaN         NaN
# 117            NaN                      NaN     NaN         NaN
# 118            NaN                      NaN     NaN         NaN
#
#     purchase_places stores      countries    countries_tags   countries_en  \
# 57              NaN    NaN  United States  en:united-states  United States
# 58              NaN    NaN  United States  en:united-states  United States
# 116             NaN    NaN  United States  en:united-states  United States
# 117             NaN    NaN  United States  en:united-states  United States
# 118             NaN    NaN  United States  en:united-states  United States
#
#                                       ingredients_text allergens  \
# 57   Bananas, vegetable oil (coconut oil, corn oil ...       NaN
# 58   Peanuts, wheat flour, sugar, rice flour, tapio...       NaN
# 116  Organic hazelnuts, organic cashews, organic wa...       NaN
# 117                                    Organic polenta       NaN
# 118  Rolled oats, grape concentrate, expeller press...       NaN
#
#      allergens_en traces traces_tags traces_en     serving_size  \
# 57            NaN    NaN         NaN       NaN     28 g (1 ONZ)
# 58            NaN    NaN         NaN       NaN  28 g (0.25 cup)
# 116           NaN    NaN         NaN       NaN  28 g (0.25 cup)
# 117           NaN    NaN         NaN       NaN  35 g (0.25 cup)
# 118           NaN    NaN         NaN       NaN   52 g (0.5 cup)
#
#      serving_quantity  no_nutriments  additives_n  additives  \
# 57               28.0            NaN          0.0        NaN
# 58               28.0            NaN          2.0        NaN
# 116              28.0            NaN          0.0        NaN
# 117              35.0            NaN          0.0        NaN
# 118              52.0            NaN          0.0        NaN
#
#                           additives_tags  \
# 57                                   NaN
# 58   en:e500,en:e500ii,en:e503,en:e503ii
# 116                                  NaN
# 117                                  NaN
# 118                                  NaN
#
#                                           additives_en  \
# 57                                                 NaN
# 58   E500 - Sodium carbonates,E500ii - Sodium hydro...
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
#
#      ingredients_from_palm_oil_n  ingredients_from_palm_oil  \
# 57                           0.0                        NaN
# 58                           0.0                        NaN
# 116                          0.0                        NaN
# 117                          0.0                        NaN
# 118                          0.0                        NaN
#
#     ingredients_from_palm_oil_tags  ingredients_that_may_be_from_palm_oil_n  \
# 57                             NaN                                      0.0
# 58                             NaN                                      0.0
# 116                            NaN                                      0.0
# 117                            NaN                                      0.0
# 118                            NaN                                      0.0
#
#      ingredients_that_may_be_from_palm_oil  \
# 57                                     NaN
# 58                                     NaN
# 116                                    NaN
# 117                                    NaN
# 118                                    NaN
#
#     ingredients_that_may_be_from_palm_oil_tags  nutriscore_score  \
# 57                                         NaN               NaN
# 58                                         NaN               NaN
# 116                                        NaN               NaN
# 117                                        NaN               NaN
# 118                                        NaN               NaN
#
#     nutriscore_grade  nova_group pnns_groups_1 pnns_groups_2  \
# 57               NaN         4.0       unknown       unknown
# 58               NaN         NaN       unknown       unknown
# 116              NaN         NaN       unknown       unknown
# 117              NaN         NaN       unknown       unknown
# 118              NaN         NaN       unknown       unknown
#
#                                                 states  \
# 57   en:to-be-completed, en:nutrition-facts-complet...
# 58   en:to-be-completed, en:nutrition-facts-complet...
# 116  en:to-be-completed, en:nutrition-facts-complet...
# 117  en:to-be-completed, en:nutrition-facts-complet...
# 118  en:to-be-completed, en:nutrition-facts-complet...
#
#                                            states_tags  \
# 57   en:to-be-completed,en:nutrition-facts-complete...
# 58   en:to-be-completed,en:nutrition-facts-complete...
# 116  en:to-be-completed,en:nutrition-facts-complete...
# 117  en:to-be-completed,en:nutrition-facts-complete...
# 118  en:to-be-completed,en:nutrition-facts-complete...
#
#                                              states_en brand_owner  \
# 57   To be completed,Nutrition facts completed,Ingr...         NaN
# 58   To be completed,Nutrition facts completed,Ingr...         NaN
# 116  To be completed,Nutrition facts completed,Ingr...         NaN
# 117  To be completed,Nutrition facts completed,Ingr...         NaN
# 118  To be completed,Nutrition facts completed,Ingr...         NaN
#
#      ecoscore_score_fr ecoscore_grade_fr main_category main_category_en  \
# 57                 NaN               NaN           NaN              NaN
# 58                 NaN               NaN           NaN              NaN
# 116                NaN               NaN           NaN              NaN
# 117                NaN               NaN           NaN              NaN
# 118                NaN               NaN           NaN              NaN
#
#     image_url image_small_url image_ingredients_url  \
# 57        NaN             NaN                   NaN
# 58        NaN             NaN                   NaN
# 116       NaN             NaN                   NaN
# 117       NaN             NaN                   NaN
# 118       NaN             NaN                   NaN
#
#     image_ingredients_small_url image_nutrition_url image_nutrition_small_url  \
# 57                          NaN                 NaN                       NaN
# 58                          NaN                 NaN                       NaN
# 116                         NaN                 NaN                       NaN
# 117                         NaN                 NaN                       NaN
# 118                         NaN                 NaN                       NaN
#
#      energy-kj_100g  energy-kcal_100g  energy_100g  energy-from-fat_100g  \
# 57              NaN             536.0       2243.0                   NaN
# 58              NaN             464.0       1941.0                   NaN
# 116             NaN             607.0       2540.0                   NaN
# 117             NaN             371.0       1552.0                   NaN
# 118             NaN             462.0       1933.0                   NaN
#
#      fat_100g  saturated-fat_100g  -butyric-acid_100g  -caproic-acid_100g  \
# 57      28.57               28.57                 NaN                 NaN
# 58      17.86                0.00                 NaN                 NaN
# 116     57.14                5.36                 NaN                 NaN
# 117      1.43                 NaN                 NaN                 NaN
# 118     18.27                1.92                 NaN                 NaN
#
#      -caprylic-acid_100g  -capric-acid_100g  -lauric-acid_100g  \
# 57                   NaN                NaN                NaN
# 58                   NaN                NaN                NaN
# 116                  NaN                NaN                NaN
# 117                  NaN                NaN                NaN
# 118                  NaN                NaN                NaN
#
#      -myristic-acid_100g  -palmitic-acid_100g  -stearic-acid_100g  \
# 57                   NaN                  NaN                 NaN
# 58                   NaN                  NaN                 NaN
# 116                  NaN                  NaN                 NaN
# 117                  NaN                  NaN                 NaN
# 118                  NaN                  NaN                 NaN
#
#      -arachidic-acid_100g  -behenic-acid_100g  -lignoceric-acid_100g  \
# 57                    NaN                 NaN                    NaN
# 58                    NaN                 NaN                    NaN
# 116                   NaN                 NaN                    NaN
# 117                   NaN                 NaN                    NaN
# 118                   NaN                 NaN                    NaN
#
#      -cerotic-acid_100g  -montanic-acid_100g  -melissic-acid_100g  \
# 57                  NaN                  NaN                  NaN
# 58                  NaN                  NaN                  NaN
# 116                 NaN                  NaN                  NaN
# 117                 NaN                  NaN                  NaN
# 118                 NaN                  NaN                  NaN
#
#      monounsaturated-fat_100g  polyunsaturated-fat_100g  omega-3-fat_100g  \
# 57                        NaN                       NaN               NaN
# 58                        NaN                       NaN               NaN
# 116                       NaN                       NaN               NaN
# 117                       NaN                       NaN               NaN
# 118                       NaN                       NaN               NaN
#
#      -alpha-linolenic-acid_100g  -eicosapentaenoic-acid_100g  \
# 57                          NaN                          NaN
# 58                          NaN                          NaN
# 116                         NaN                          NaN
# 117                         NaN                          NaN
# 118                         NaN                          NaN
#
#      -docosahexaenoic-acid_100g  omega-6-fat_100g  -linoleic-acid_100g  \
# 57                          NaN               NaN                  NaN
# 58                          NaN               NaN                  NaN
# 116                         NaN               NaN                  NaN
# 117                         NaN               NaN                  NaN
# 118                         NaN               NaN                  NaN
#
#      -arachidonic-acid_100g  -gamma-linolenic-acid_100g  \
# 57                      NaN                         NaN
# 58                      NaN                         NaN
# 116                     NaN                         NaN
# 117                     NaN                         NaN
# 118                     NaN                         NaN
#
#      -dihomo-gamma-linolenic-acid_100g  omega-9-fat_100g  -oleic-acid_100g  \
# 57                                 NaN               NaN               NaN
# 58                                 NaN               NaN               NaN
# 116                                NaN               NaN               NaN
# 117                                NaN               NaN               NaN
# 118                                NaN               NaN               NaN
#
#      -elaidic-acid_100g  -gondoic-acid_100g  -mead-acid_100g  \
# 57                  NaN                 NaN              NaN
# 58                  NaN                 NaN              NaN
# 116                 NaN                 NaN              NaN
# 117                 NaN                 NaN              NaN
# 118                 NaN                 NaN              NaN
#
#      -erucic-acid_100g  -nervonic-acid_100g  trans-fat_100g  cholesterol_100g  \
# 57                 NaN                  NaN             0.0              0.02
# 58                 NaN                  NaN             0.0              0.00
# 116                NaN                  NaN             NaN               NaN
# 117                NaN                  NaN             NaN               NaN
# 118                NaN                  NaN             NaN               NaN
#
#      carbohydrates_100g  sugars_100g  -sucrose_100g  -glucose_100g  \
# 57                64.29        14.29            NaN            NaN
# 58                60.71        17.86            NaN            NaN
# 116               17.86         3.57            NaN            NaN
# 117               77.14          NaN            NaN            NaN
# 118               63.46        11.54            NaN            NaN
#
#      -fructose_100g  -lactose_100g  -maltose_100g  -maltodextrins_100g  \
# 57              NaN            NaN            NaN                  NaN
# 58              NaN            NaN            NaN                  NaN
# 116             NaN            NaN            NaN                  NaN
# 117             NaN            NaN            NaN                  NaN
# 118             NaN            NaN            NaN                  NaN
#
#      starch_100g  polyols_100g  fiber_100g  -soluble-fiber_100g  \
# 57           NaN           NaN         3.6                  NaN
# 58           NaN           NaN         7.1                  NaN
# 116          NaN           NaN         7.1                  NaN
# 117          NaN           NaN         5.7                  NaN
# 118          NaN           NaN         7.7                  NaN
#
#      -insoluble-fiber_100g  proteins_100g  casein_100g  serum-proteins_100g  \
# 57                     NaN           3.57          NaN                  NaN
# 58                     NaN          17.86          NaN                  NaN
# 116                    NaN          17.86          NaN                  NaN
# 117                    NaN           8.57          NaN                  NaN
# 118                    NaN          13.46          NaN                  NaN
#
#      nucleotides_100g  salt_100g  sodium_100g  alcohol_100g  vitamin-a_100g  \
# 57                NaN       0.00         0.00           NaN             0.0
# 58                NaN       0.64         0.25           NaN             0.0
# 116               NaN       1.22         0.49           NaN             NaN
# 117               NaN        NaN          NaN           NaN             NaN
# 118               NaN        NaN          NaN           NaN             NaN
#
#      beta-carotene_100g  vitamin-d_100g  vitamin-e_100g  vitamin-k_100g  \
# 57                  NaN             NaN             NaN             NaN
# 58                  NaN             NaN             NaN             NaN
# 116                 NaN             NaN             NaN             NaN
# 117                 NaN             NaN             NaN             NaN
# 118                 NaN             NaN             NaN             NaN
#
#      vitamin-c_100g  vitamin-b1_100g  vitamin-b2_100g  vitamin-pp_100g  \
# 57             0.02              NaN              NaN              NaN
# 58             0.00              NaN              NaN              NaN
# 116             NaN              NaN              NaN              NaN
# 117             NaN              NaN              NaN              NaN
# 118             NaN              NaN              NaN              NaN
#
#      vitamin-b6_100g  vitamin-b9_100g  folates_100g  vitamin-b12_100g  \
# 57               NaN              NaN           NaN               NaN
# 58               NaN              NaN           NaN               NaN
# 116              NaN              NaN           NaN               NaN
# 117              NaN              NaN           NaN               NaN
# 118              NaN              NaN           NaN               NaN
#
#      biotin_100g  pantothenic-acid_100g  silica_100g  bicarbonate_100g  \
# 57           NaN                    NaN          NaN               NaN
# 58           NaN                    NaN          NaN               NaN
# 116          NaN                    NaN          NaN               NaN
# 117          NaN                    NaN          NaN               NaN
# 118          NaN                    NaN          NaN               NaN
#
#      potassium_100g  chloride_100g  calcium_100g  phosphorus_100g  iron_100g  \
# 57              NaN            NaN          0.00              NaN   1.29e-03
# 58              NaN            NaN          0.07              NaN   1.29e-03
# 116             NaN            NaN          0.14              NaN   5.14e-03
# 117             NaN            NaN           NaN              NaN        NaN
# 118             NaN            NaN          0.04              NaN   3.46e-03
#
#      magnesium_100g  zinc_100g  copper_100g  manganese_100g  fluoride_100g  \
# 57              NaN        NaN          NaN             NaN            NaN
# 58              NaN        NaN          NaN             NaN            NaN
# 116             NaN        NaN          NaN             NaN            NaN
# 117             NaN        NaN          NaN             NaN            NaN
# 118             NaN        NaN          NaN             NaN            NaN
#
#      selenium_100g  chromium_100g  molybdenum_100g  iodine_100g  \
# 57             NaN            NaN              NaN          NaN
# 58             NaN            NaN              NaN          NaN
# 116            NaN            NaN              NaN          NaN
# 117            NaN            NaN              NaN          NaN
# 118            NaN            NaN              NaN          NaN
#
#      caffeine_100g  taurine_100g  ph_100g  fruits-vegetables-nuts_100g  \
# 57             NaN           NaN      NaN                          NaN
# 58             NaN           NaN      NaN                          NaN
# 116            NaN           NaN      NaN                          NaN
# 117            NaN           NaN      NaN                          NaN
# 118            NaN           NaN      NaN                          NaN
#
#      fruits-vegetables-nuts-dried_100g  fruits-vegetables-nuts-estimate_100g  \
# 57                                 NaN                                   NaN
# 58                                 NaN                                   NaN
# 116                                NaN                                   NaN
# 117                                NaN                                   NaN
# 118                                NaN                                   NaN
#
#      collagen-meat-protein-ratio_100g  cocoa_100g  chlorophyl_100g  \
# 57                                NaN         NaN              NaN
# 58                                NaN         NaN              NaN
# 116                               NaN         NaN              NaN
# 117                               NaN         NaN              NaN
# 118                               NaN         NaN              NaN
#
#      carbon-footprint_100g  carbon-footprint-from-meat-or-fish_100g  \
# 57                     NaN                                      NaN
# 58                     NaN                                      NaN
# 116                    NaN                                      NaN
# 117                    NaN                                      NaN
# 118                    NaN                                      NaN
#
#      nutrition-score-fr_100g  nutrition-score-uk_100g  glycemic-index_100g  \
# 57                       NaN                      NaN                  NaN
# 58                       NaN                      NaN                  NaN
# 116                      NaN                      NaN                  NaN
# 117                      NaN                      NaN                  NaN
# 118                      NaN                      NaN                  NaN
#
#      water-hardness_100g  choline_100g  phylloquinone_100g  beta-glucan_100g  \
# 57                   NaN           NaN                 NaN               NaN
# 58                   NaN           NaN                 NaN               NaN
# 116                  NaN           NaN                 NaN               NaN
# 117                  NaN           NaN                 NaN               NaN
# 118                  NaN           NaN                 NaN               NaN
#
#      inositol_100g  carnitine_100g
# 57             NaN             NaN
# 58             NaN             NaN
# 116            NaN             NaN
# 117            NaN             NaN
# 118            NaN             NaN

# %% [markdown]
# #### Traiter les doublons

# %%
df_dup = df.duplicated().sum()
if df_dup>0:
    df = df.drop_duplicates()
    print('Total doublons:  ',df_dup)

# %%
List_projet =  ['product_name','categories','nutriscore_grade','nutriscore_score','nova_group','ecoscore_grade_fr','ecoscore_score_fr',
                'countries_en','origins_tags','labels','allergens','additives_en','ingredients_from_palm_oil_n',
                'ingredients_that_may_be_from_palm_oil_n','fat_100g','saturated-fat_100g','energy-kcal_100g','energy-kj_100g',
                'carbon-footprint-from-meat-or-fish_100g','carbohydrates_100g','omega-3-fat_100g','omega-6-fat_100g','omega-9-fat_100g',
                'cholesterol_100g','trans-fat_100g','sugars_100g','proteins_100g','salt_100g','sodium_100g',
                'alcohol_100g','vitamin-a_100g','vitamin-d_100g','vitamin-e_100g',
                'vitamin-k_100g','vitamin-c_100g','vitamin-b1_100g','vitamin-b2_100g','vitamin-pp_100g','calcium_100g',
                'vitamin-b6_100g','vitamin-b9_100g','vitamin-b12_100g','fruits-vegetables-nuts_100g']
filtered_df = df.loc[:,List_projet]

# %%
def remove_outlier(df_in,q1value,q3value):
    import copy
    df_out = copy.deepcopy(df_in)
    
    q1 =df_in.quantile(q1value)
    q3 =df_in.quantile(q3value)
    iqr = q3-q1  
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    #===== Remove
    df_out = df_in[~((df_in < fence_low) |(df_in > fence_high)).any(axis=1)]
    return df_out

# %%
def isnull_values_sum(df):
    taille = len(df)/2
    null   = df.isnull().sum() 
    b=null.le(taille)
    cols_to_keep = df.columns[b]
    df = df.loc[:, cols_to_keep]
    return df

# %%
def plot_box_plot(df,xlabel_name,ylabel_name):
    color = dict(boxes='black', whiskers='black', medians='red', caps='black')
    ax = df.plot.box(color=color,whiskerprops = dict(linestyle='-',linewidth=2.0, color='black'),figsize=(24, 8),fontsize=18)
    ax.set_xlabel(xlabel_name,fontsize=18)
    ax.set_ylabel(ylabel_name,fontsize=18)
    plt.grid(color='k', linestyle='-', linewidth=.1)
    plt.xticks(rotation=90)
    ax.label_outer() 

    plt.savefig(figure_name,format='jpeg',dpi=100,bbox_inches='tight')

# %% [markdown]
# #### Traiter les valeurs aberrants

# %%
figure_name ='../../P3/FIGURES/Outliers.jpeg'

ylabel = " "
xlabel = " "
ax = plot_box_plot(filtered_df,xlabel,ylabel)

# %%
q1value=0.05
q3value=0.95
df1 = remove_outlier(filtered_df,q1value,q3value)
# Out:
# <ipython-input-8-0d6550d21d0c>:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_out = df_in[~((df_in < fence_low) |(df_in > fence_high)).any(axis=1)]
# <ipython-input-8-0d6550d21d0c>:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_out = df_in[~((df_in < fence_low) |(df_in > fence_high)).any(axis=1)]

# %%
figure_name ='../../P3/FIGURES/Outliers.jpeg'

ylabel = " "
xlabel = " "
ax = plot_box_plot(df1,xlabel,ylabel)

# %% [markdown]
# Energy_cal_100g, energy_kj_100g et carbon-footprint-from-meat-or-fish_100g ont des valeurs
# aberrant tres eleve. Je vais appliquer unfiltrage pour chaque variable

# %% [markdown]
# #### Traiter les valeurs manquants

# %%
Null = df1.isnull().sum() 
Na = df1.isna().sum()
df_NaN = pd.DataFrame(data=Na)
print(df_NaN)
# Out:
#                                              0
# product_name                               449
# categories                                4233
# nutriscore_grade                          6357
# nutriscore_score                          6357
# nova_group                                4132
# ecoscore_grade_fr                        11499
# ecoscore_score_fr                        11499
# countries_en                                 0
# origins_tags                             13969
# labels                                   13107
# allergens                                12401
# additives_en                              6922
# ingredients_from_palm_oil_n               3312
# ingredients_that_may_be_from_palm_oil_n   3312
# fat_100g                                  1661
# saturated-fat_100g                        3233
# energy-kcal_100g                          1652
# energy-kj_100g                           13982
# carbon-footprint-from-meat-or-fish_100g  14051
# carbohydrates_100g                        1649
# omega-3-fat_100g                         14069
# omega-6-fat_100g                         14069
# omega-9-fat_100g                         14069
# cholesterol_100g                          5980
# trans-fat_100g                            6119
# sugars_100g                               2300
# proteins_100g                             1666
# salt_100g                                 1963
# sodium_100g                               1963
# alcohol_100g                             14023
# vitamin-a_100g                            7000
# vitamin-d_100g                           13757
# vitamin-e_100g                           14068
# vitamin-k_100g                           14058
# vitamin-c_100g                            6884
# vitamin-b1_100g                          13460
# vitamin-b2_100g                          13463
# vitamin-pp_100g                          13419
# calcium_100g                              6136
# vitamin-b6_100g                          13781
# vitamin-b9_100g                          13845
# vitamin-b12_100g                         13857
# fruits-vegetables-nuts_100g              14067

# %% [markdown]
# Je fait le choix de dans un premier temps supprimer certain variables que sont truffée de données manquantes (plus de 50% de valeurs manquantes).
# J'ai egalement choisi de ne pas imputer les valeurs manquantes cars pour le projet, cela peut engendrer des erreurs sur la proposition des produits sains.

# %%
df_final = isnull_values_sum(df1)
